# %% [markdown]
# # Stage 09 — Homework Starter Notebook
#
# In the lecture, we learned how to create engineered features. Now it’s your turn to apply those ideas to your own project data.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../../project/data/processed/Merged_full.csv')
df.head()
L=df.columns[2:7]
RT = L[:4]
# Out:
# Index(['VTI_close', 'VOO_close', 'SPY_close', 'SCHD_close', 'VIXY_close'], dtype='object')

# %% [markdown]
# ## TODO: Implement at least 2 engineered features here

# %%
# Example template:
for i in L:
    df[f'{i}_change'] = df[i].pct_change()

#above captures the percent change from each day after day 1 taking the further returns
df["SPY_VIXY_corr5"] = df["SPY_close_change"].rolling(5).corr(df["VIXY_close_change"])
#above captures the correlation against the SPY 5 day average and % change in VIXY shows the correlation to volatility for any given week
df

# df['spend_income_ratio'] = df['monthly_spend'] / df['income']  # TODO: Your feature
# # Add rationale in markdown below
# Out:
#       Unnamed: 0        date  VTI_close  VOO_close  SPY_close  SCHD_close  \
# 0           3012  2011-10-20     62.090      55.59     121.66      24.980
# 1           3013  2011-10-21     63.260      56.66     123.97      25.470
# 2           3014  2011-10-24     64.320      57.38     125.49      25.607
# 3           3015  2011-10-25     63.006      56.27     123.05      25.187
# 4           3016  2011-10-26     63.690      56.81     124.30      25.447
# ...          ...         ...        ...        ...        ...         ...
# 3475        6487  2025-08-18    316.590     591.36     643.30      27.260
# 3476        6488  2025-08-19    314.670     588.13     639.81      27.450
# 3477        6489  2025-08-20    313.840     586.58     638.11      27.510
# 3478        6490  2025-08-21    312.760     584.27     635.55      27.520
# 3479        6491  2025-08-22    318.180     593.21     645.31      27.950
#
#       VIXY_close  VTI_close_change  VOO_close_change  SPY_close_change  \
# ...

# %% [markdown]
# ### Rationale for Feature 1 & 2
# # Rationale 1
#
# The first shows the daily percent change which gives us a much better indication of overall performance, where we can check based on the daily changes without calculation.
#
# # Rationale 2
#
# The second shows the 5 day rolling percent change compared to the VIXY percent change. This gives an indication of the general average correlation per week against the volatility.
